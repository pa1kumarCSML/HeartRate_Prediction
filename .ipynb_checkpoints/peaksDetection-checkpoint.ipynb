# %%
#Necessary imports

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import openpyxl
import pandas as pd
import dlib
import seaborn as sns


from scipy.signal import butter, filtfilt, lfilter
from scipy.fft import fft, fftfreq
from datetime import datetime
from scipy.signal import find_peaks

# %%
#Constants
low_cutoff = 0.75
high_cutoff = 2.5
fps=0
fs = 2 * high_cutoff

#Paths
dlib_path = 'dlib_files/shape_predictor_68_face_landmarks.dat'
# Load face detector and facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(dlib_path)


#pulses values
pulses_forehead=[]
pulses_leftc=[]
pulses_rightc=[]
# pulses_fullf=[]

# Create a new DataFrame with new columns data

# %%
#Utility functions

# def setValues():
#     #Constants
#     low_cutoff = 0.75
#     high_cutoff = 2.5
#     fs = 2 * high_cutoff    
#     #pulses values
#     # pulses_fullf=[]


def calculate_pulse_signal(roi,pulses):
    
    B, G, R = cv2.split(roi)
    
    #Normalizing R,G,B channels
    
    Rn = R / np.mean(R)
    Gn = G / np.mean(G)
    Bn = B / np.mean(B)    
    
    #CHROM Signals
    
    Xs = 3*Rn - 2*Gn
    Ys = 1.5*Rn + Gn - 1.5*Bn
    
    Rf = apply_bandpass_filter(Rn)
    Gf = apply_bandpass_filter(Gn)
    Bf = apply_bandpass_filter(Bn)
    Xf = apply_bandpass_filter(Xs)
    Yf = apply_bandpass_filter(Ys)

    alpha = np.std(Xf) / np.std(Yf)

    Signal = 3*(1-(alpha/2))*Rf - 2*(1 + (alpha/2))*Gf + ((3*alpha)/2)*Bf
    
    pulses.append(np.mean(Signal))  

def apply_bandpass_filter(channel, order=5):
    b, a = butter_bandpass(order)
    y = filtfilt(b, a, channel, axis=0,padlen=0)
    return y

def butter_bandpass(order=5):
    nyquist = 0.5 * fs  # Nyquist frequency
    lowcut_norm = low_cutoff / nyquist 
    highcut_norm = high_cutoff / nyquist
    b, a = butter(order, [lowcut_norm, highcut_norm-0.1], btype='band')
    return b, a

def find_peak(pulses):
    peaks, pro = find_peaks(pulses , height=np.mean(pulses))
    # Output results
    # print("Indices of peaks:", peaks)
    # print("pro: ",pro['peak_heights'])
    return peaks, pro['peak_heights']

# %%
# Open video file

def calculateResult(file_path):
    data = {
    'filepath': np.nan,
    'peakscf' : np.nan,
    'peakscl' : np.nan,
    'peakscr' : np.nan,
    'maxif': np.nan,
    'maxil':np.nan,
    'maxir':np.nan,
    'avgif':np.nan,
    'avgil':np.nan,
    'avgir':np.nan,
    'commonpeaksc': np.nan,
    'facecount': np.nan,
    'error':0
    }
    
    cap = cv2.VideoCapture(file_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    global pulses_forehead,pulses_leftc,pulses_rightc
    
    pulses_forehead=[]
    pulses_leftc=[]
    pulses_rightc=[]
    
    # Process each frame in the video
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
    
        # Convert frame to grayscale
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
        # Detect faces in the frame
        faces = detector(gray)
        
        if(len(faces) > 1):
            data['facecount'] = len(faces)
            print('more than one face')
            return data
            break
    
        # Process each detected face
        for face in faces:
            # Detect facial landmarks
            landmarks = predictor(gray, face)
            
            # Identify forehead region based on landmarks
            forehead_r1=[0,0,0,0] #x1,x2,y1,y2
            
            forehead_r1[0] = landmarks.part(21).x # Left eyebrow-x
            forehead_r1[1] = landmarks.part(22).x  # Right eyebrow-x
            forehead_r1_height=int((forehead_r1[1] - forehead_r1[0]))
            forehead_r1[2] = landmarks.part(21).y - forehead_r1_height # Left eyebrow-y
            forehead_r1[3] = landmarks.part(22).y # Right eyebrow-y
            
            # Identify left cheek region-1 based on landmarks
            leftc_r1=[0,0,0,0] #x1,x2,y1,y2
            
            leftc_r1[0]=landmarks.part(41).x
            leftc_r1[1]=landmarks.part(39).x
            leftc_r1[2]=landmarks.part(28).y
            leftc_r1[3]=landmarks.part(30).y
    
            # Identify right cheek region-1 based on landmarks
            rightc_r1=[0,0,0,0] #x1,x2,y1,y2
            
            rightc_r1[0]=landmarks.part(42).x
            rightc_r1[1]=landmarks.part(46).x
            rightc_r1[2]=landmarks.part(28).y
            rightc_r1[3]=landmarks.part(30).y
            
            try:
                calculate_pulse_signal(frame[forehead_r1[2]:forehead_r1[3],forehead_r1[0]:forehead_r1[1]],pulses_forehead)
                calculate_pulse_signal(frame[leftc_r1[2]:leftc_r1[3],leftc_r1[0]:leftc_r1[1]],pulses_leftc)
                calculate_pulse_signal(frame[rightc_r1[2]:rightc_r1[3],rightc_r1[0]:rightc_r1[1]],pulses_rightc)   
            except Exception as e:
                print(e,file_path)
                data['error']=1
                return data
    
        # Exit if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            # handle if q pressed
            break
    # Release video capture
    cap.release()
    # print(pulses_forehead)
    peaksf, hf=find_peak(pulses_forehead)
    peaksl, hl=find_peak(pulses_leftc)
    peaksr, hr=find_peak(pulses_rightc)

    common_peaks = set(peaksf).intersection(peaksl, peaksr)
    # print('common i:',common_peaks)
    
    data = {
    'filepath':file_path,
    'peakscf' : len(peaksf),
    'peakscl' : len(peaksl),
    'peakscr' : len(peaksr),
    'maxif': np.max(hf),
    'maxil':np.max(hl),
    'maxir':np.max(hr),
    'avgif':np.mean(pulses_forehead),
    'avgil':np.mean(pulses_leftc),
    'avgir':np.mean(pulses_rightc),
    'commonpeaksc' :len(common_peaks),
    'facecount': 1,
    'error':0
    }    
    return data

# %%
excel_file = 'celebDF_DS.xlsx'  # Replace with the path to your Excel file
output_file1='peaks1.xlsx'
output_file2='peaks2.xlsx'
# video_path = 'videos/real/jenny.mp4'
isold = True
results=[]

# Read the existing Excel file    
existing_df = pd.read_excel(excel_file)
# print(calculateResult(video_path))
count=1
for filepath in existing_df['filepath']:
        print(f"processing: {filepath}")
        if(count<472):
            count+=1
            continue
        result = calculateResult(filepath)
        results.append(result)
        try:
            results_df = pd.DataFrame(results)
            results_df.to_excel(output_file1,index=False)
        except Exception as e:
            print(f"An error occurred: {e}")
    
# updating Results DataSet
# print(results)
try:
    results_df = pd.DataFrame(results)
    results_df.to_excel(output_file2,index=False)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id0_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id10_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id11_0010.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id12_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0010.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0011.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0012.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0013.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0014.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id13_0015.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0010.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0011.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0012.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id16_0013.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id17_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id1_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id2_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id3_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id4_0009.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0000.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0001.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0002.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0003.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0004.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0005.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0006.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0007.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\id6_0008.mp4
# processing: C:/Users/dpava/Desktop/celeb_df_v1/Celeb-real\